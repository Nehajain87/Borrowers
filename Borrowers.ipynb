# %% [markdown]
# # Importing necessary libraries for the project

# %%
import numpy as np 
import pandas as pd
import os

# %% [markdown]
# # Data Extraction

# %%
# import the 5k_borrowers_data.csv file using the pandas library
Borrowers = pd.read_csv('5k_borrowers_data.csv')

# %%
Borrowers.head(100)
# Out:
#                    Name Date of Birth  Gender Marital Status  Phone Number  \
# 0          Khushi Balan    19-02-1986    Male         Single    2169182416
# 1      Umang Chatterjee    13-08-1980    Male        Married    4521712306
# 2            Adira Dara    05-08-1995  Female        Widowed    4615155004
# 3            Anvi Saini    16-11-2001    Male        Married  914836846677
# 4           Kartik Kade    09-07-1979    Male        Widowed  910186397558
# ..                  ...           ...     ...            ...           ...
# 95           Heer Walla    22-11-1987    Male        Married    8922854743
# 96         Taimur Verma    29-08-1986    Male         Single    6180710728
# 97      Rasha Jayaraman    09-08-1995    Male        Widowed    8865800490
# 98  Chirag Ramakrishnan    30-12-1982    Male         Single  913076913137
# 99         Jayesh Tella    13-07-2003    Male       Divorced    1809691833
#
# ...

# %% [markdown]
# # Finding Null Values

# %%
Borrowers.isnull().sum()
# Out:
# Name                            0
# Date of Birth                   0
# Gender                          0
# Marital Status                  0
# Phone Number                    0
# Email Address                   0
# Mailing Address                 0
# Language Preference             0
# Geographical Location           0
# Credit Score                    0
# Loan Type                       0
# Loan Amount                     0
# Loan Term                       0
# Interest Rate                   0
# Loan Purpose                    0
# EMI                             0
# IP Address                      0
# Geolocation                     0
# Repayment History               0
# Days Left to Pay Current EMI    0
# Delayed Payment                 0
# dtype: int64

# %%
Borrowers.shape
# Out:
# (5000, 21)

# %%
Borrowers.describe()
# Out:
#        Phone Number  Credit Score   Loan Amount    Loan Term  Interest Rate  \
# count  5.000000e+03   5000.000000   5000.000000  5000.000000    5000.000000
# mean   2.989236e+11    572.723600  55293.283600     8.058000       0.200690
# std    4.255826e+11    156.942055  26027.140578     4.257307       0.057756
# min    5.800290e+05    300.000000  10057.000000     1.000000       0.100000
# 25%    3.669391e+09    439.000000  32771.250000     4.000000       0.150000
# 50%    7.383758e+09    565.000000  55671.000000     8.000000       0.200000
# 75%    9.122299e+11    708.000000  77737.750000    12.000000       0.250000
# max    9.199829e+11    850.000000  99999.000000    15.000000       0.300000
#
#                  EMI  Days Left to Pay Current EMI
# count    5000.000000                   5000.000000
# mean    12363.778246                      8.115200
# std     15225.846309                      4.331429
# min       735.330000                      1.000000
# ...

# %%
Borrowers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Name                          5000 non-null   object
#  1   Date of Birth                 5000 non-null   object
#  2   Gender                        5000 non-null   object
#  3   Marital Status                5000 non-null   object
#  4   Phone Number                  5000 non-null   int64
#  5   Email Address                 5000 non-null   object
#  6   Mailing Address               5000 non-null   object
#  7   Language Preference           5000 non-null   object
#  8   Geographical Location         5000 non-null   object
#  9   Credit Score                  5000 non-null   int64
#  10  Loan Type                     5000 non-null   object
#  11  Loan Amount                   5000 non-null   int64
# ...

# %%
Borrowers.isnull().sum()/len(Borrowers)*100
# Out:
# Name                            0.0
# Date of Birth                   0.0
# Gender                          0.0
# Marital Status                  0.0
# Phone Number                    0.0
# Email Address                   0.0
# Mailing Address                 0.0
# Language Preference             0.0
# Geographical Location           0.0
# Credit Score                    0.0
# Loan Type                       0.0
# Loan Amount                     0.0
# Loan Term                       0.0
# Interest Rate                   0.0
# Loan Purpose                    0.0
# EMI                             0.0
# IP Address                      0.0
# Geolocation                     0.0
# Repayment History               0.0
# Days Left to Pay Current EMI    0.0
# Delayed Payment                 0.0
# dtype: float64

# %%
duplicate =Borrowers[Borrowers.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [Name, Date of Birth, Gender, Marital Status, Phone Number, Email Address, Mailing Address, Language Preference, Geographical Location, Credit Score, Loan Type, Loan Amount, Loan Term, Interest Rate, Loan Purpose, EMI, IP Address, Geolocation, Repayment History, Days Left to Pay Current EMI, Delayed Payment]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# #  Data Transformation

# %%
# Drop all the rows which contains [] from the dataset.
#no missing Value found.
#no duplicate value found. 
#[] cant be raplce through Mean or Median as column type is Object.

# %%
Borrowers = Borrowers.drop(Borrowers[Borrowers['Repayment History'] == '[]'].index)

# %%
Borrowers.head(10)
# Out:
#                 Name Date of Birth  Gender Marital Status  Phone Number  \
# 0       Khushi Balan    19-02-1986    Male         Single    2169182416
# 1   Umang Chatterjee    13-08-1980    Male        Married    4521712306
# 2         Adira Dara    05-08-1995  Female        Widowed    4615155004
# 3         Anvi Saini    16-11-2001    Male        Married  914836846677
# 5       Rohan Sekhon    31-07-1980    Male        Widowed    5864147671
# 6     Purab Randhawa    19-10-1966  Female         Single    5187626325
# 7      Vardaniya Roy    03-08-1998  Female        Widowed    3958629885
# 8          Piya Ravi    06-10-2001    Male       Divorced  913408234563
# 9   Rati Swaminathan    01-01-1992  Female        Widowed    7508064439
# 10        Aaina Mani    02-01-1960  Female        Married    2344611182
#
#               Email Address                                   Mailing Address  \
# 0       xbhakta@example.com                       29/74, Mander, Kulti 156906
# ...

# %%
Borrowers.shape
# Out:
# (4224, 21)

# %% [markdown]
# # #Data Load

# %%
Borrowers.to_csv('borrowers.csv')
